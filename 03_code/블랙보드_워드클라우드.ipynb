# %%
import numpy as np 
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('C:/Users/samsung/Desktop/블랙보드 공모전/02_data/블랙보드만족도조사_학생_데이터분석공모전.csv', encoding='utf-8', )
data
# Out:
#                         Timestamp    UniqID              소속    학년 성별  \
# 0     2022/10/18 1:45:14 PM GMT+9  C5559ekz    교육대학원 생물교육전공  석사과정  여
# 1    2022/10/24 10:11:29 AM GMT+9  S9340unw      정보대학 컴퓨터학과   1학년  여
# 2    2022/10/24 10:14:12 AM GMT+9  Q6348ilg       경영대학 경영학과   4학년  여
# 3    2022/10/24 10:23:01 AM GMT+9  F7696nak     문과대학 중어중문학과   3학년  여
# 4    2022/10/24 10:26:54 AM GMT+9  C5856rtq        이과대학 화학과   2학년  여
# ..                            ...       ...             ...   ... ..
# 215   2022/11/06 3:35:25 PM GMT+9  I1519dwz  정보보호대학 스마트보안학부   1학년  남
# 216   2022/11/06 3:55:13 PM GMT+9  N9471unp      정보대학 컴퓨터학과   2학년  여
# 217   2022/11/06 9:27:50 PM GMT+9  X229401j    이과대학 지구환경과학과   2학년  여
# 218  2022/11/06 10:58:07 PM GMT+9  K807327s    고려대학 반도체물리학과   4학년  남
# 219  2022/11/06 11:43:14 PM GMT+9  K4641ngi       심리대학 심리학부   1학년  남
#
#      1. 블랙보드 시스템에 전반적으로 만족하십니까? 2. 학기중 블랙보드에는 얼마나 자주 접속하십니까?  \
# 0                             4                    하루에 3회 이상
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 55 columns):
#  #   Column                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                      --------------  -----
#  0   Timestamp                                                                                   220 non-null    object
#  1   UniqID                                                                                      220 non-null    object
#  2   소속                                                                                          220 non-null    object
#  3   학년                                                                                          220 non-null    object
#  4   성별                                                                                          220 non-null    object
# ...

# %%
data.iloc[:,[5,8,10,11,12,13,23,24,26,27,29,31,33,35,37,39,41,43,45,47,50]] = data.iloc[:,[5,8,10,11,12,13,23,24,26,27,29,31,33,35,37,39,41,43,45,47,50]].astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 55 columns):
#  #   Column                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                      --------------  -----
#  0   Timestamp                                                                                   220 non-null    object
#  1   UniqID                                                                                      220 non-null    object
#  2   소속                                                                                          220 non-null    object
#  3   학년                                                                                          220 non-null    object
#  4   성별                                                                                          220 non-null    object
# ...

# %%
data_s = data[(data['1. 블랙보드 시스템에 전반적으로 만족하십니까?']==4)|(data['1. 블랙보드 시스템에 전반적으로 만족하십니까?']==5)]
data_s
# Out:
#                         Timestamp    UniqID               소속    학년 성별  \
# 0     2022/10/18 1:45:14 PM GMT+9  C5559ekz     교육대학원 생물교육전공  석사과정  여
# 2    2022/10/24 10:14:12 AM GMT+9  Q6348ilg        경영대학 경영학과   4학년  여
# 3    2022/10/24 10:23:01 AM GMT+9  F7696nak      문과대학 중어중문학과   3학년  여
# 5    2022/10/24 10:30:54 AM GMT+9  L19921wq  일반대학원 문화유산학협동과정  석사과정  여
# 6    2022/10/24 10:32:58 AM GMT+9  I1349sdo        문과대학/한문학과   3학년  여
# ..                            ...       ...              ...   ... ..
# 215   2022/11/06 3:35:25 PM GMT+9  I1519dwz   정보보호대학 스마트보안학부   1학년  남
# 216   2022/11/06 3:55:13 PM GMT+9  N9471unp       정보대학 컴퓨터학과   2학년  여
# 217   2022/11/06 9:27:50 PM GMT+9  X229401j     이과대학 지구환경과학과   2학년  여
# 218  2022/11/06 10:58:07 PM GMT+9  K807327s     고려대학 반도체물리학과   4학년  남
# 219  2022/11/06 11:43:14 PM GMT+9  K4641ngi        심리대학 심리학부   1학년  남
#
#     1. 블랙보드 시스템에 전반적으로 만족하십니까? 2. 학기중 블랙보드에는 얼마나 자주 접속하십니까?  \
# 0                            4                    하루에 3회 이상
# ...

# %%
data_s_nh = data_s[(data_s['46. 차세대 학습관리시스템(LMS)를 도입하는 것에 대해 어떻게 생각하십니까? ']=='현재 학습관리시스템(LMS) 블랙보드 유지')]
data_s_nh
# Out:
#                         Timestamp    UniqID                  소속    학년 성별  \
# 2    2022/10/24 10:14:12 AM GMT+9  Q6348ilg           경영대학 경영학과   4학년  여
# 3    2022/10/24 10:23:01 AM GMT+9  F7696nak         문과대학 중어중문학과   3학년  여
# 6    2022/10/24 10:32:58 AM GMT+9  I1349sdo           문과대학/한문학과   3학년  여
# 12   2022/10/24 10:39:17 AM GMT+9  U5078mpj  일반대학원 미디어학과 미디어학전공  박사과정  여
# 15   2022/10/24 10:40:29 AM GMT+9  M8938b1a      기술경영대학원 기술경영학과  석사과정  남
# ..                            ...       ...                 ...   ... ..
# 210   2022/11/05 1:11:04 AM GMT+9  O4635oih           고려대학교 화학과   1학년  여
# 211   2022/11/05 7:17:52 PM GMT+9  J573227f        공과대학 산업경영공학과   2학년  여
# 215   2022/11/06 3:35:25 PM GMT+9  I1519dwz      정보보호대학 스마트보안학부   1학년  남
# 216   2022/11/06 3:55:13 PM GMT+9  N9471unp          정보대학 컴퓨터학과   2학년  여
# 217   2022/11/06 9:27:50 PM GMT+9  X229401j        이과대학 지구환경과학과   2학년  여
#
#     1. 블랙보드 시스템에 전반적으로 만족하십니까? 2. 학기중 블랙보드에는 얼마나 자주 접속하십니까?  \
# ...

# %%
data_s_nh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88 entries, 2 to 217
# Data columns (total 55 columns):
#  #   Column                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                      --------------  -----
#  0   Timestamp                                                                                   88 non-null     object
#  1   UniqID                                                                                      88 non-null     object
#  2   소속                                                                                          88 non-null     object
#  3   학년                                                                                          88 non-null     object
#  4   성별                                                                                          88 non-null     object
# ...

# %%
# Q23

# %%
pd.options.display.max_rows = 99

# %%
sen_23 = data_s_nh['24. 모바일 APP 이용 시 개선되었으면 하는 점을 자유롭게 작성하여 주십시오.']

sen_23 = sen_23.reset_index(drop=True)

sen_23 = sen_23.replace(np.NaN, "")

sen_23
# Out:
# 0
# 1                                               알림기능 선택
# 2
# 3                                          수정 기능 사용의 한계
# 4                                강의파일 다운로드가 가능하도록 기능 추가
# 5                     ui가 블랙보드 웹페이지와 비슷하게 만들어졌으면 좋겠습니다.
# 6                        활동스트림에 과거 수강내역 숨김이 있었으면 좋겠습니다.
# 7                    간혹 접속이 불안정함. 강의 자료 다운이 안되는 경우가 있음.
# 8                         전체적으로 느리고 로그인이 맨날 풀려있어서 문제입니다
# 9
# 10                             써본적이 없어서 깔아서 사용해 봐야겠습니다.
# 11                                    접속이 안되는 경우가 많습니다.
# 12
# 13
# 14    자꾸 '귀하의 학교 계정 인증을 다시 해야합니다'가 뜨는데 매번 앱을 실행할 때마다...
# 15                      직관성이 떨어집니다. 이 부분에 대한 개선이 필요합니다.
# 16
# 17              모바일도 PC처럼 학기 별로 수강하는 강의가 분류되어 있었으면 좋겠다.
# 18    학생입장에서는 개선되었으면 하는 점은 크게 없고, 강사입장에서는 과제 제출현황을 자...
# 19                                            따로 없습니다.
# 20                수갱생이 제출한 자료 리스트를 이름순으로 정렬하면 정렬이 안됩니다.
# 21                    로그인 유지 기능, 접속 속도 개선이 필요하다고 생각합니다.
# ...

# %%
# pip install konlpy

import konlpy
from konlpy.tag import Okt
okt = Okt()

# %%
morphs_23 = []

for sentence in sen_23:
    morphs_23.append(okt.pos(sentence))
    
print(morphs_23)
# Out:
# [[], [('알림', 'Noun'), ('기능', 'Noun'), ('선택', 'Noun')], [], [('수정', 'Noun'), ('기능', 'Noun'), ('사용', 'Noun'), ('의', 'Josa'), ('한계', 'Noun')], [('강의', 'Noun'), ('파일', 'Noun'), ('다운로드', 'Noun'), ('가', 'Josa'), ('가능하도록', 'Adjective'), ('기능', 'Noun'), ('추가', 'Noun')], [('ui', 'Alpha'), ('가', 'Verb'), ('블랙보드', 'Noun'), ('웹페이지', 'Noun'), ('와', 'Josa'), ('비슷하게', 'Adjective'), ('만들어졌으면', 'Verb'), ('좋겠습니다', 'Adjective'), ('.', 'Punctuation')], [('활동', 'Noun'), ('스트림', 'Noun'), ('에', 'Josa'), ('과거', 'Noun'), ('수강', 'Noun'), ('내', 'Determiner'), ('역', 'Noun'), ('숨김이', 'Verb'), ('있었으면', 'Adjective'), ('좋겠습니다', 'Adjective'), ('.', 'Punctuation')], [('간혹', 'Noun'), ('접속', 'Noun'), ('이', 'Josa'), ('불안정함', 'Adjective'), ('.', 'Punctuation'), ('강의', 'Noun'), ('자료', 'Noun'), ('다운', 'Noun'), ('이', 'Josa'), ('안되는', 'Adjective'), ('경우', 'Noun'), ('가', 'Josa'), ('있음', 'Adjective'), ('.', 'Punctuation')], [('전체', 'Noun'), ('적', 'Suffix'), ('으로', 'Josa'), ('느리고', 'Adjective'), ('로그인', 'Noun'), ('이', 'Josa'), 
# ...

# %%
noun_list_23 = []

for i in morphs_23:
    for word, tag in i:
        if (tag in ['Noun', 'Alpha']):
            noun_list_23.append(word)


from collections import Counter

count_23 = Counter(noun_list_23)
words_23 = (dict(count_23.most_common()))
print(words_23)
# Out:
# {'로그인': 16, '접속': 15, '개선': 14, '경우': 13, '학기': 13, '강의': 12, '모바일': 12, '코스': 10, '현재': 9, '기능': 8, '사용': 8, '앱': 8, '수강': 7, '알림': 6, '활동': 6, '때': 6, '시': 6, '업데이트': 6, '것': 6, '스트림': 5, '이': 5, '수': 5, '블랙보드': 4, '과거': 4, '자료': 4, '부분': 4, '유지': 4, 'APP': 4, '더': 4, '오류': 4, 'current': 4, '선택': 3, '파일': 3, '문제': 3, '다시': 3, '인터넷': 3, '점': 3, '제출': 3, '이용': 3, '화면': 3, '상단': 3, '자동': 3, '좀': 3, '매우': 3, '설정': 3, '과목': 3, '자주': 3, '다운로드': 2, '추가': 2, '웹페이지': 2, '다운': 2, '자꾸': 2, '계정': 2, '또': 2, '직관': 2, '대한': 2, 'PC': 2, '입장': 2, '과제': 2, '정렬': 2, '속도': 2, 'app': 2, '메뉴': 2, 'UI': 2, '살짝': 2, '먼저': 2, '중인': 2, '탭': 2, '노출': 2, '태블릿': 2, '버튼': 2, '최근': 2, '종종': 2, '제대로': 2, '로': 2, '뜸': 2, '확인': 2, '재': 2, '강중인': 2, '줌': 2, '바로': 2, '수정': 1, '한계': 1, 'ui': 1, '역': 1, '간혹': 1, '전체': 1, '본적': 1, '귀하': 1, '학교': 1, '인증': 1, '매번': 1, '실행': 1, '정보': 1, '처럼': 1, '별로': 1, '분류': 1, '학생': 1, '크게': 1, '강사': 1, '현황': 1, '볼': 1, '갱생': 1, '리스트': 1, '이름': 1, '순': 1, '생각': 1, 'collaborate': 1, 're
# ...

# %%
for i in range(len(sen_23)):
    a = sen_23.iloc[i]
    sen_23.iloc[i] = a.lower()

for i in range(len(sen_23)):
    a = sen_23.iloc[i]
    sen_23.iloc[i] = a.replace('앱','app')
    
for i in range(len(sen_23)):
    a = sen_23.iloc[i]
    sen_23.iloc[i] = a.replace('어플','app')
    
for i in range(len(sen_23)):
    a = sen_23.iloc[i]
    sen_23.iloc[i] = a.replace('수강중인','수강 중인')
    
for i in range(len(sen_23)):
    a = sen_23.iloc[i]
    sen_23.iloc[i] = a.replace('current','현재')
    
for i in range(len(sen_23)):
    a = sen_23.iloc[i]
    sen_23.iloc[i] = a.replace('stream','스트림')
    
for i in range(len(sen_23)):
    a = sen_23.iloc[i]
    sen_23.iloc[i] = a.replace('courses','코스')
    
for i in range(len(sen_23)):
    a = sen_23.iloc[i]
    sen_23.iloc[i] = a.replace('수갱생','수강생')
    
for i in range(len(sen_23)):
    a = sen_23.iloc[i]
    sen_23.iloc[i] = a.replace('문제','오류')
    
for i in range(len(sen_23)):
    a = sen_23.iloc[i]
    sen_23.iloc[i] = a.replace('반응속도','반응 속도')
    
for i in range(len(sen_23)):
    a = sen_23.iloc[i]
    sen_23.iloc[i] = a.replace('콜라보레이트','collaborate')
    
for i in range(len(sen_23)):
    a = sen_23.iloc[i]
    sen_23.iloc[i] = a.replace('자꾸','자주')
    
for i in range(len(sen_23)):
    a = sen_23.iloc[i]
    sen_23.iloc[i] = a.replace('다운로드','download')

for i in range(len(sen_23)):
    a = sen_23.iloc[i]
    sen_23.iloc[i] = a.replace('다운','download')

for i in range(len(sen_23)):
    a = sen_23.iloc[i]
    sen_23.iloc[i] = a.replace('탭','tab')
    
for i in range(len(sen_23)):
    a = sen_23.iloc[i]
    sen_23.iloc[i] = a.replace('로그인시','로그인 시')
    
for i in range(len(sen_23)):
    a = sen_23.iloc[i]
    sen_23.iloc[i] = a.replace('최상단','상단')
    
for i in range(len(sen_23)):
    a = sen_23.iloc[i]
    sen_23.iloc[i] = a.replace('오류로','오류')
    
for i in range(len(sen_23)):
    a = sen_23.iloc[i]
    sen_23.iloc[i] = a.replace('최신','업데이트')
    
for i in range(len(sen_23)):
    a = sen_23.iloc[i]
    sen_23.iloc[i] = a.replace('갱신','업데이트')

# %%
morphs_23 = []

for sentence in sen_23:
    morphs_23.append(okt.pos(sentence))


noun_list_23 = []

for i in morphs_23:
    for word, tag in i:
        if (tag in ['Noun', 'Alpha']) and len(word) > 1 and ("경우" not in word) and ("부분" not in word) and ("중인" not in word) and ("대한" not in word):
            noun_list_23.append(word)


from collections import Counter

count_23 = Counter(noun_list_23)
words_23 = (dict(count_23.most_common()))
print(words_23)
# Out:
# {'로그인': 17, '접속': 15, 'app': 15, '개선': 14, '학기': 13, '현재': 13, '강의': 12, '모바일': 12, '코스': 11, '수강': 9, '기능': 8, '사용': 8, '업데이트': 8, '오류': 7, '알림': 6, '활동': 6, '스트림': 6, '자주': 5, 'download': 4, 'ui': 4, '블랙보드': 4, '과거': 4, '자료': 4, '유지': 4, '상단': 4, '선택': 3, '파일': 3, '다시': 3, '인터넷': 3, 'pc': 3, '제출': 3, '속도': 3, '이용': 3, '화면': 3, 'tab': 3, '자동': 3, '매우': 3, '설정': 3, '과목': 3, '추가': 2, '웹페이지': 2, '계정': 2, '직관': 2, '입장': 2, '과제': 2, '정렬': 2, 'collaborate': 2, '메뉴': 2, '살짝': 2, '갤럭시': 2, '먼저': 2, '노출': 2, '태블릿': 2, '버튼': 2, '최근': 2, '종종': 2, '제대로': 2, '확인': 2, '바로': 2, '수정': 1, '한계': 1, '간혹': 1, '전체': 1, '본적': 1, '귀하': 1, '학교': 1, '인증': 1, '매번': 1, '실행': 1, '정보': 1, '처럼': 1, '별로': 1, '분류': 1, '학생': 1, '크게': 1, '강사': 1, '현황': 1, '수강생': 1, '리스트': 1, '이름': 1, '생각': 1, 'recording': 1, '재생': 1, '상대': 1, '오히려': 1, '직접': 1, '버전': 1, '구성': 1, '학년': 1, '순차': 1, '목록': 1, '연동': 1, '상태': 1, '새로고침': 1, '불가': 1, '계속': 1, '풀림': 1, '글씨': 1, '크기': 1, '피드백': 1, '반응': 1, '안드로이드': 1, '활용': 1, '노트': 1, '이후': 
# ...

# %%
# min-max normalization
df_23 = pd.DataFrame(words_23.values())
normalization_df_23 = (df_23 - df_23.min())/(df_23.max() - df_23.min())

a_23 = pd.concat([pd.DataFrame(words_23.keys()), normalization_df_23], axis=1).to_dict('split')['data']
a_23 = dict(a_23)

print(a_23)
# Out:
# {'로그인': 1.0, '접속': 0.875, 'app': 0.875, '개선': 0.8125, '학기': 0.75, '현재': 0.75, '강의': 0.6875, '모바일': 0.6875, '코스': 0.625, '수강': 0.5, '기능': 0.4375, '사용': 0.4375, '업데이트': 0.4375, '오류': 0.375, '알림': 0.3125, '활동': 0.3125, '스트림': 0.3125, '자주': 0.25, 'download': 0.1875, 'ui': 0.1875, '블랙보드': 0.1875, '과거': 0.1875, '자료': 0.1875, '유지': 0.1875, '상단': 0.1875, '선택': 0.125, '파일': 0.125, '다시': 0.125, '인터넷': 0.125, 'pc': 0.125, '제출': 0.125, '속도': 0.125, '이용': 0.125, '화면': 0.125, 'tab': 0.125, '자동': 0.125, '매우': 0.125, '설정': 0.125, '과목': 0.125, '추가': 0.0625, '웹페이지': 0.0625, '계정': 0.0625, '직관': 0.0625, '입장': 0.0625, '과제': 0.0625, '정렬': 0.0625, 'collaborate': 0.0625, '메뉴': 0.0625, '살짝': 0.0625, '갤럭시': 0.0625, '먼저': 0.0625, '노출': 0.0625, '태블릿': 0.0625, '버튼': 0.0625, '최근': 0.0625, '종종': 0.0625, '제대로': 0.0625, '확인': 0.0625, '바로': 0.0625, '수정': 0.0, '한계': 0.0, '간혹': 0.0, '전체': 0.0, '본적': 0.0, '귀하': 0.0, '학교': 0.0, '인증': 0.0, '매번': 0.0, '실행': 0.0, '정보': 0.0, '처럼': 0.0, '별로': 0.0, '분류': 0.0, '학생': 0.0, '크게': 
# ...

# %%
# pip install wordcloud
from wordcloud import WordCloud

import nltk
from nltk.corpus import stopwords

# %%
# 갈색~주황색
def my_tf_color_func(dictionary):
    def my_tf_color_func_inner(word, font_size, position, orientation, random_state=None, **kwargs):
        return "hsl(35, 80%%, %d%%)" % (60 * (1- dictionary[word] + (1/3)))
    return my_tf_color_func_inner

# %%
wordcloud_23 = WordCloud(font_path = 'C:/Users/samsung/Downloads/BMJUA_ttf.ttf', width=3000, height=2000,
                          background_color = 'white', color_func=my_tf_color_func(a_23)).generate_from_frequencies(a_23) 

plt.imshow(wordcloud_23)
plt.axis('off')
plt.show()

# %%
# Q35

# %%
sen_35 = data_s_nh['36. 그룹활동(토론, 블로그, 저널) 기능에서 개선되었으면 하는 점을 자유롭게 작성하여 주십시오.']

sen_35 = sen_35.reset_index(drop=True)

sen_35 = sen_35.replace(np.NaN, "")

sen_35
# Out:
# 0
# 1                                                    없음
# 2
# 3                                              전반적으로 만족
# 4
# 5
# 6                                                없습니다.
# 7                                          크게 활용한 적이 없음
# 8                                    로딩이 느려서 더 빨랐으면 합니다
# 9
# 10                                                    .
# 11                                               연결 오류
# 12
# 13
# 14                                                없습니다.
# 15                      자유롭게 토론할 분위기 조성면에서 부족한 점이 보입니다.
# 16
# 17                         토론 관련 공지가 토론 창에서도 제공되었으면 좋겠다
# 18                              그룹활동 컨텐츠들은 사용해보지 않았습니다.
# 19                                               없습니다.
# 20                                                \n없음.
# 21                   토론 기능 활성화를 위한 알림 강화 등이 이루어졌으면 합니다.
# 22
# 23                                           사용해본적없습니다.
# 24
# 25                                    글 작성과 댓글 작성이 혼동됨.
# 26
# 27
# 28
# 29
# 30
# 31
# ...

# %%
morphs_35 = []

for sentence in sen_35:
    morphs_35.append(okt.pos(sentence))
    
print(morphs_35)
# Out:
# [[], [('없음', 'Adjective')], [], [('전반', 'Noun'), ('적', 'Suffix'), ('으로', 'Josa'), ('만족', 'Noun')], [], [], [('없습니다', 'Adjective'), ('.', 'Punctuation')], [('크게', 'Noun'), ('활용', 'Noun'), ('한', 'Josa'), ('적', 'Noun'), ('이', 'Josa'), ('없음', 'Adjective')], [('로딩', 'Noun'), ('이', 'Josa'), ('느려서', 'Adjective'), ('더', 'Noun'), ('빨랐으면', 'Adjective'), ('합니다', 'Verb')], [], [('.', 'Punctuation')], [('연결', 'Noun'), ('오류', 'Noun')], [], [], [('없습니다', 'Adjective'), ('.', 'Punctuation')], [('자유롭게', 'Adjective'), ('토론', 'Noun'), ('할', 'Verb'), ('분위기', 'Noun'), ('조성면', 'Noun'), ('에서', 'Josa'), ('부족한', 'Adjective'), ('점', 'Noun'), ('이', 'Josa'), ('보입니다', 'Verb'), ('.', 'Punctuation')], [], [('토론', 'Noun'), ('관련', 'Noun'), ('공지', 'Noun'), ('가', 'Josa'), ('토론', 'Noun'), ('창', 'Noun'), ('에서도', 'Josa'), ('제공', 'Noun'), ('되었으면', 'Verb'), ('좋겠다', 'Adjective')], [('그룹', 'Noun'), ('활동', 'Noun'), ('컨텐츠', 'Noun'), ('들', 'Suffix'), ('은', 'Josa'), ('사용', 'Noun'), ('해보지', 'Verb'), ('않았습니다', 'Verb'), ('.', 'Punct
# ...

# %%
noun_list_35 = []

for i in morphs_35:
    for word, tag in i:
        if (tag in ['Noun']):
            noun_list_35.append(word)


from collections import Counter

count_35 = Counter(noun_list_35)
words_35 = (dict(count_35.most_common()))
print(words_35)
# Out:
# {'댓글': 12, '토론': 10, '사용': 9, '기능': 8, '것': 8, '경우': 7, '적': 6, '글': 6, '더': 5, '대한': 5, '알림': 4, '활용': 3, '수': 3, '크게': 2, '점': 2, '활동': 2, '등': 2, '작성': 2, '직관': 2, '수정': 2, '삭제': 2, '좀': 2, '부분': 2, '때': 2, '화면': 2, '실제': 2, '논의': 2, '형식': 2, '확인': 2, '답글': 2, '거의': 2, '개선': 2, '방': 2, '수업': 2, '전반': 1, '만족': 1, '로딩': 1, '연결': 1, '오류': 1, '분위기': 1, '조성면': 1, '관련': 1, '공지': 1, '창': 1, '제공': 1, '그룹': 1, '컨텐츠': 1, '활성화': 1, '위': 1, '강화': 1, '혼동': 1, '시스템': 1, '및': 1, '글씨': 1, '크기': 1, '해도': 1, '적도': 1, '제안': 1, '눈': 1, '첫': 1, '게시': 1, '구분': 1, '종종': 1, '매우': 1, '실': 1, '페이지': 1, '익명': 1, '선택': 1, '보기': 1, '디자인': 1, '특정': 1, '주제': 1, '메인': 1, '아티': 1, '밑': 1, '달리': 1, '외': 1, '서로': 1, '현': 1, '소셜네트워크서비스': 1, '설정': 1, '듯': 1, '블로그': 1, '널': 1, '위키': 1, '알': 1, '이': 1, '설명': 1, '마련': 1, '생각': 1, '함': 1, '새': 1, '업데이트': 1, '시': 1, '지금': 1, '중': 1, '해당': 1, '하나': 1, '뒤': 1, '이건': 1, '자신': 1, '교수': 1, '참여': 1, '볼': 1, '동시': 1, '의견': 1, '제시': 1, '수준': 1, '구성': 1}

# %%
for i in range(len(sen_35)):
    a = sen_35.iloc[i]
    sen_35.iloc[i] = a.replace('답글','댓글')
    
for i in range(len(sen_35)):
    a = sen_35.iloc[i]
    sen_35.iloc[i] = a.replace('없습니다','없음')
    
for i in range(len(sen_35)):
    a = sen_35.iloc[i]
    sen_35.iloc[i] = a.replace('없었습니다','없음')

for i in range(len(sen_35)):
    a = sen_35.iloc[i]
    sen_35.iloc[i] = a.replace('없다','없음')
    
for i in range(len(sen_35)):
    a = sen_35.iloc[i]
    sen_35.iloc[i] = a.replace('없어서','없음')
    
for i in range(len(sen_35)):
    a = sen_35.iloc[i]
    sen_35.iloc[i] = a.replace('없어','없음')
    
for i in range(len(sen_35)):
    a = sen_35.iloc[i]
    sen_35.iloc[i] = a.replace('보기 편한','직관적인')
    
for i in range(len(sen_35)):
    a = sen_35.iloc[i]
    sen_35.iloc[i] = a.replace('눈에 띄게','직관적이게')
    
for i in range(len(sen_35)):
    a = sen_35.iloc[i]
    sen_35.iloc[i] = a.replace('논의','토론')
    
for i in range(len(sen_35)):
    a = sen_35.iloc[i]
    sen_35.iloc[i] = a.replace('로딩','연결')
    
for i in range(len(sen_35)):
    a = sen_35.iloc[i]
    sen_35.iloc[i] = a.replace('활용','사용')
    
for i in range(len(sen_35)):
    a = sen_35.iloc[i]
    sen_35.iloc[i] = a.replace('사용안해봄','사용해본적 없음')

for i in range(len(sen_35)):
    a = sen_35.iloc[i]
    sen_35.iloc[i] = a.replace('쓰지','사용하지')

# %%
morphs_35 = []

for sentence in sen_35:
    morphs_35.append(okt.pos(sentence))


noun_list_35 = []

for i in morphs_35:
    for word, tag in i:
        if (tag in ['Noun', 'Alpha']) and len(word) > 1 and ("경우" not in word) and ("부분" not in word) and ("대한" not in word):
            noun_list_35.append(word)

for i in morphs_35:
    for word, tag in i:
        if ("글" == word) or ('없음' in word):
            noun_list_35.append(word)

from collections import Counter

count_35 = Counter(noun_list_35)
words_35 = (dict(count_35.most_common()))
print(words_35)
# Out:
# {'없음': 17, '댓글': 14, '사용': 13, '토론': 12, '기능': 8, '글': 6, '알림': 4, '직관': 4, '크게': 2, '연결': 2, '활동': 2, '작성': 2, '수정': 2, '삭제': 2, '화면': 2, '실제': 2, '형식': 2, '확인': 2, '거의': 2, '개선': 2, '수업': 2, '전반': 1, '만족': 1, '오류': 1, '분위기': 1, '조성면': 1, '관련': 1, '공지': 1, '제공': 1, '그룹': 1, '컨텐츠': 1, '활성화': 1, '강화': 1, '혼동': 1, '시스템': 1, '글씨': 1, '크기': 1, '해도': 1, '적도': 1, 'thread': 1, '제안': 1, '게시': 1, '구분': 1, '종종': 1, '매우': 1, '페이지': 1, '익명': 1, '선택': 1, '디자인': 1, '특정': 1, '주제': 1, '메인': 1, '아티': 1, '달리': 1, '서로': 1, '소셜네트워크서비스': 1, '설정': 1, '블로그': 1, '위키': 1, '설명': 1, '마련': 1, '생각': 1, '업데이트': 1, '지금': 1, '해당': 1, '하나': 1, 'sort': 1, '이건': 1, '자신': 1, '교수': 1, '참여': 1, '동시': 1, '의견': 1, '제시': 1, '수준': 1, '구성': 1}

# %%
# min-max normalization
df_35 = pd.DataFrame(words_35.values())
normalization_df_35 = (df_35 - df_35.min())/(df_35.max() - df_35.min())

a_35 = pd.concat([pd.DataFrame(words_35.keys()), normalization_df_35], axis=1).to_dict('split')['data']
a_35 = dict(a_35)

print(a_35)
# Out:
# {'없음': 1.0, '댓글': 0.8125, '사용': 0.75, '토론': 0.6875, '기능': 0.4375, '글': 0.3125, '알림': 0.1875, '직관': 0.1875, '크게': 0.0625, '연결': 0.0625, '활동': 0.0625, '작성': 0.0625, '수정': 0.0625, '삭제': 0.0625, '화면': 0.0625, '실제': 0.0625, '형식': 0.0625, '확인': 0.0625, '거의': 0.0625, '개선': 0.0625, '수업': 0.0625, '전반': 0.0, '만족': 0.0, '오류': 0.0, '분위기': 0.0, '조성면': 0.0, '관련': 0.0, '공지': 0.0, '제공': 0.0, '그룹': 0.0, '컨텐츠': 0.0, '활성화': 0.0, '강화': 0.0, '혼동': 0.0, '시스템': 0.0, '글씨': 0.0, '크기': 0.0, '해도': 0.0, '적도': 0.0, 'thread': 0.0, '제안': 0.0, '게시': 0.0, '구분': 0.0, '종종': 0.0, '매우': 0.0, '페이지': 0.0, '익명': 0.0, '선택': 0.0, '디자인': 0.0, '특정': 0.0, '주제': 0.0, '메인': 0.0, '아티': 0.0, '달리': 0.0, '서로': 0.0, '소셜네트워크서비스': 0.0, '설정': 0.0, '블로그': 0.0, '위키': 0.0, '설명': 0.0, '마련': 0.0, '생각': 0.0, '업데이트': 0.0, '지금': 0.0, '해당': 0.0, '하나': 0.0, 'sort': 0.0, '이건': 0.0, '자신': 0.0, '교수': 0.0, '참여': 0.0, '동시': 0.0, '의견': 0.0, '제시': 0.0, '수준': 0.0, '구성': 0.0}

# %%
wordcloud_35 = WordCloud(font_path = 'C:/Users/samsung/Downloads/BMJUA_ttf.ttf', width=3000, height=2000,
                          background_color = 'white', color_func=my_tf_color_func(a_35)).generate_from_frequencies(a_35) 

plt.imshow(wordcloud_35)
plt.axis('off')
plt.show()

# %%
# Q25

# %%
sen_25 = data_s_nh['26. 코스 화면에서 개선되었으면 하는 점을 자유롭게 작성하여 주십시오.']

sen_25 = sen_25.reset_index(drop=True)

sen_25 = sen_25.replace(np.NaN, "")

sen_25
# Out:
# 0
# 1                                              코스 순서 배열
# 2
# 3                                        코스 순서 편집 가능하도록
# 4                           특정 학기만 필터링된 리스트만 볼수 있으면 좋겠음
# 5                                     현재도 이용에 불편이 없습니다.
# 6                                     코스 화면 구성에 만족합니다.
# 7                             코스 순서를 자유롭게 배열할 수 있으면 좋겠음
# 8     코스 순서 자유롭게 배열 ...\n코스 더 직관적으로 디자인 변경\n자연 이미지 말...
# 9
# 10                   강의 소개 사진이 강의와 연계되거나 자연이 아니였으면 좋겠다.
# 11                       코스 순서를 사용자 맞춤으로 변경할 수 있었으면 좋겠음
# 12
# 13
# 14    1. 원하는 학기의 코스만 뜨게 만들 수 있으면 좋겠음. 2. 숨기기 기능이 있으면...
# 15                              코스 화면 구성은 지금 상태로 만족합니다.
# 16
# 17                           코스 화면에 강의별로 메모 기능이 있으면 좋겠다
# 18          과거 수강한 코스들이 없어지는데, 좀 더 오랜시간 보관되어있었으면 좋겠습니다.
# 19            지난 학기의 학습현황은 메인 화면에 안 보이도록 하면 좋을 것 같습니다.
# 20    코스별 학습현황 페이지의 반이 공백인데 공백인 부분을 활용하여 1년 코스가 보였으면...
# 21                     코스 알림을 코스 화면에서 확인할 수 있었으면 좋겠습니다.
# 22
# ...

# %%
morphs_25 = []

for sentence in sen_25:
    morphs_25.append(okt.pos(sentence))
    
print(morphs_25)
# Out:
# [[], [('코스', 'Noun'), ('순서', 'Noun'), ('배열', 'Noun')], [], [('코스', 'Noun'), ('순서', 'Noun'), ('편집', 'Noun'), ('가능하도록', 'Adjective')], [('특정', 'Noun'), ('학기', 'Noun'), ('만', 'Josa'), ('필터', 'Noun'), ('링', 'Noun'), ('된', 'Verb'), ('리스트', 'Noun'), ('만', 'Josa'), ('볼수', 'Verb'), ('있으면', 'Adjective'), ('좋겠음', 'Adjective')], [('현재', 'Noun'), ('도', 'Josa'), ('이용', 'Noun'), ('에', 'Josa'), ('불편', 'Noun'), ('이', 'Josa'), ('없습니다', 'Adjective'), ('.', 'Punctuation')], [('코스', 'Noun'), ('화면', 'Noun'), ('구성', 'Noun'), ('에', 'Josa'), ('만족합니다', 'Adjective'), ('.', 'Punctuation')], [('코스', 'Noun'), ('순서', 'Noun'), ('를', 'Josa'), ('자유롭게', 'Adjective'), ('배열', 'Noun'), ('할', 'Verb'), ('수', 'Noun'), ('있으면', 'Adjective'), ('좋겠음', 'Adjective')], [('코스', 'Noun'), ('순서', 'Noun'), ('자유롭게', 'Adjective'), ('배열', 'Noun'), ('...', 'Punctuation'), ('\n', 'Foreign'), ('코스', 'Noun'), ('더', 'Noun'), ('직관', 'Noun'), ('적', 'Suffix'), ('으로', 'Josa'), ('디자인', 'Noun'), ('변경', 'Noun'), ('\n', 'Foreign'), ('자연', 'Noun'), ('
# ...

# %%
noun_list_25 = []

for i in morphs_25:
    for word, tag in i:
        if (tag in ['Noun', 'Alpha']):
            noun_list_25.append(word)


from collections import Counter

count_25 = Counter(noun_list_25)
words_25 = (dict(count_25.most_common()))
print(words_25)
# Out:
# {'코스': 46, '순서': 18, '학기': 18, '수': 18, '배열': 14, '화면': 12, '현재': 10, '이미지': 7, '강의': 7, '수업': 6, '설정': 5, '과목': 5, '가장': 5, '자동': 5, '구성': 4, '변경': 4, '별로': 4, '부분': 4, '위': 4, '목록': 4, '개선': 4, '배치': 4, '접속': 4, '직관': 3, '사진': 3, '기능': 3, '수강': 3, '별': 3, '타일': 3, '상단': 3, '모바일': 3, '고정': 3, '즐겨찾기': 3, '경우': 3, '이': 3, '특정': 2, '더': 2, '자연': 2, '교수': 2, '상태': 2, '메모': 2, '좀': 2, '지난': 2, '학습': 2, '현황': 2, '것': 2, '공백': 2, '확인': 2, '형식': 2, '각': 2, '크게': 2, '또한': 2, '먼저': 2, '버튼': 2, '첫': 2, '그': 2, '함': 2, '등': 2, '볼': 2, '명시': 2, '편집': 1, '필터': 1, '링': 1, '리스트': 1, '이용': 1, '불편': 1, '디자인': 1, '소개': 1, '계': 1, '사용자': 1, '맞춤': 1, '구성은': 1, '지금': 1, '과거': 1, '시간': 1, '보관': 1, '메인': 1, '안': 1, '페이지': 1, '반': 1, '활용': 1, '알림': 1, '대로': 1, '방식': 1, '풍경사진': 1, '네모': 1, '그냥': 1, '일반': 1, '정사': 1, '사항': 1, '자료': 1, '업로드': 1, '점': 1, '우측': 1, '숫자': 1, '배지': 1, '웹': 1, '기재': 1, '문제': 1, '때문': 1, '매우': 1, '대체로': 1, '앱': 1, '새로고침': 1, '만족': 1, '주간': 1, '계획': 1, '표': 1, '바탕': 1, '요일': 1, 'UI': 
# ...

# %%
for i in range(len(sen_25)):
    a = sen_25.iloc[i]
    sen_25.iloc[i] = a.lower()

for i in range(len(sen_25)):
    a = sen_25.iloc[i]
    sen_25.iloc[i] = a.replace('앱','app')
    
for i in range(len(sen_25)):
    a = sen_25.iloc[i]
    sen_25.iloc[i] = a.replace('위','상단')
    
for i in range(len(sen_25)):
    a = sen_25.iloc[i]
    sen_25.iloc[i] = a.replace('우선','상단')
    
for i in range(len(sen_25)):
    a = sen_25.iloc[i]
    sen_25.iloc[i] = a.replace('커스터마이징','customizing')
    
for i in range(len(sen_25)):
    a = sen_25.iloc[i]
    sen_25.iloc[i] = a.replace('자율화','customizing')
    
for i in range(len(sen_25)):
    a = sen_25.iloc[i]
    sen_25.iloc[i] = a.replace('자유롭게 변경','자유롭게 배열')

for i in range(len(sen_25)):
    a = sen_25.iloc[i]
    sen_25.iloc[i] = a.replace('자유롭게','customizing')
    
for i in range(len(sen_25)):
    a = sen_25.iloc[i]
    sen_25.iloc[i] = a.replace('원하는 대로','원하는대로')
    
for i in range(len(sen_25)):
    a = sen_25.iloc[i]
    sen_25.iloc[i] = a.replace('원하는대로','customizing')
    
for i in range(len(sen_25)):
    a = sen_25.iloc[i]
    sen_25.iloc[i] = a.replace('사용자 맞춤으로','customizing')
    
for i in range(len(sen_25)):
    a = sen_25.iloc[i]
    sen_25.iloc[i] = a.replace('이용자가 설정','customizing')
    
for i in range(len(sen_25)):
    a = sen_25.iloc[i]
    sen_25.iloc[i] = a.replace('배치','배열')
    
for i in range(len(sen_25)):
    a = sen_25.iloc[i]
    sen_25.iloc[i] = a.replace('구성은','구성')

for i in range(len(sen_25)):
    a = sen_25.iloc[i]
    sen_25.iloc[i] = a.replace('코스순서','코스 순서')
    
for i in range(len(sen_25)):
    a = sen_25.iloc[i]
    sen_25.iloc[i] = a.replace('코스 순서','순서')
    
for i in range(len(sen_25)):
    a = sen_25.iloc[i]
    sen_25.iloc[i] = a.replace('사진','이미지')
    
for i in range(len(sen_25)):
    a = sen_25.iloc[i]
    sen_25.iloc[i] = a.replace('수강중인','수강 중인')

# %%
morphs_25 = []

for sentence in sen_25:
    morphs_25.append(okt.pos(sentence))


noun_list_25 = []

for i in morphs_25:
    for word, tag in i:
        if (tag in ['Noun', 'Alpha']) and len(word) > 1 and ("경우" not in word) and ("부분" not in word) and ("별로" not in word) and ("또한" not in word):
            noun_list_25.append(word)


from collections import Counter

count_25 = Counter(noun_list_25)
words_25 = (dict(count_25.most_common()))
print(words_25)
# Out:
# {'코스': 30, '배열': 19, 'customizing': 19, '순서': 18, '학기': 18, '화면': 12, '이미지': 11, '현재': 10, '상단': 9, '강의': 7, '수업': 6, '구성': 5, '과목': 5, '가장': 5, '자동': 5, '수강': 4, '목록': 4, '설정': 4, '개선': 4, '접속': 4, '직관': 3, '변경': 3, '기능': 3, '타일': 3, '모바일': 3, '고정': 3, '즐겨찾기': 3, '특정': 2, '자연': 2, '교수': 2, '상태': 2, '메모': 2, '지난': 2, '학습': 2, '현황': 2, '공백': 2, '확인': 2, '형식': 2, 'app': 2, '크게': 2, '먼저': 2, '버튼': 2, '명시': 2, '편집': 1, '필터': 1, '리스트': 1, '이용': 1, '불편': 1, '디자인': 1, '소개': 1, '지금': 1, '과거': 1, '시간': 1, '보관': 1, '메인': 1, '페이지': 1, '활용': 1, '알림': 1, '방식': 1, '풍경': 1, '네모': 1, '그냥': 1, '일반': 1, '정사': 1, '사항': 1, '자료': 1, '업로드': 1, '우측': 1, '숫자': 1, '배지': 1, '기재': 1, '문제': 1, '때문': 1, '매우': 1, '대체로': 1, '새로고침': 1, '만족': 1, '주간': 1, '계획': 1, '바탕': 1, '요일': 1, 'ui': 1, '지원': 1, '랜덤': 1, '배정': 1, '학생': 1, '지정': 1, '최신': 1, '이전': 1, '교육': 1, '온라인': 1, '아예': 1, '거나': 1, '통해': 1, '계속': 1, '간혹': 1, '중이': 1, '항상': 1, '바로': 1, '보이': 1, '그림': 1, '좀더': 1, '나열': 1, '문제점': 1, '중인': 1, '추가': 1, '색깔': 1, '변화
# ...

# %%
# min-max normalization
df_25 = pd.DataFrame(words_25.values())
normalization_df_25 = (df_25 - df_25.min())/(df_25.max() - df_25.min())

a_25 = pd.concat([pd.DataFrame(words_25.keys()), normalization_df_25], axis=1).to_dict('split')['data']
a_25 = dict(a_25)

print(a_25)
# Out:
# {'코스': 1.0, '배열': 0.6206896551724138, 'customizing': 0.6206896551724138, '순서': 0.5862068965517241, '학기': 0.5862068965517241, '화면': 0.3793103448275862, '이미지': 0.3448275862068966, '현재': 0.3103448275862069, '상단': 0.27586206896551724, '강의': 0.20689655172413793, '수업': 0.1724137931034483, '구성': 0.13793103448275862, '과목': 0.13793103448275862, '가장': 0.13793103448275862, '자동': 0.13793103448275862, '수강': 0.10344827586206896, '목록': 0.10344827586206896, '설정': 0.10344827586206896, '개선': 0.10344827586206896, '접속': 0.10344827586206896, '직관': 0.06896551724137931, '변경': 0.06896551724137931, '기능': 0.06896551724137931, '타일': 0.06896551724137931, '모바일': 0.06896551724137931, '고정': 0.06896551724137931, '즐겨찾기': 0.06896551724137931, '특정': 0.034482758620689655, '자연': 0.034482758620689655, '교수': 0.034482758620689655, '상태': 0.034482758620689655, '메모': 0.034482758620689655, '지난': 0.034482758620689655, '학습': 0.034482758620689655, '현황': 0.034482758620689655, '공백': 0.034482758620689655, '확인': 0.034482758620689655,
# ...

# %%
wordcloud_25 = WordCloud(font_path = 'C:/Users/samsung/Downloads/BMJUA_ttf.ttf', width=3000, height=2000,
                          background_color = 'white', color_func=my_tf_color_func(a_25)).generate_from_frequencies(a_25) 

plt.imshow(wordcloud_25)
plt.axis('off')
plt.show()

# %%
# Q47

# %%
data_nh = data[(data['46. 차세대 학습관리시스템(LMS)를 도입하는 것에 대해 어떻게 생각하십니까? ']=='현재 학습관리시스템(LMS) 블랙보드 유지')]
data_nh
# Out:
#                         Timestamp    UniqID                               소속  \
# 2    2022/10/24 10:14:12 AM GMT+9  Q6348ilg                        경영대학 경영학과
# 3    2022/10/24 10:23:01 AM GMT+9  F7696nak                      문과대학 중어중문학과
# 6    2022/10/24 10:32:58 AM GMT+9  I1349sdo                        문과대학/한문학과
# 12   2022/10/24 10:39:17 AM GMT+9  U5078mpj               일반대학원 미디어학과 미디어학전공
# 15   2022/10/24 10:40:29 AM GMT+9  M8938b1a                   기술경영대학원 기술경영학과
# 17   2022/10/24 10:47:52 AM GMT+9  R6572chw                     공과대학 전기전자공학부
# 22   2022/10/24 10:57:26 AM GMT+9  P7719mii                        문과대학 언어학과
# 23   2022/10/24 10:57:33 AM GMT+9  B7812wom           일반대학원 전기전자공학과 반도체및나노전공
# 25   2022/10/24 10:59:12 AM GMT+9  H8582rav                      자유전공학부 경영학과
# 26   2022/10/24 10:59:22 AM GMT+9  V6750ruk                         이과대학 화학과
# 29   2022/10/24 11:01:38 AM GMT+9  A2884o1p                 간호대학 간호학과 간호과학전공
# ...

# %%
sen_47 = data_nh['47. 차세대 학습관리시스템(LMS)을 도입을 희망하지 않는 이유에 대해 작성하여 주십시오.']

sen_47 = sen_47.reset_index(drop=True)

sen_47 = sen_47.replace(np.NaN, "")

sen_47
# Out:
# 0                                             변경시 혼란 가중
# 1                                                 현재 만족
# 2
# 3                                            시스템 불안정 우려
# 4                   새 시스템 도입에 따른 효익이 불확실하고 새로 적응하기가 불편함
# 5     교우와 예비대학생에게는 도움이 될 것 같은데 일반인에게까지 공개하는건 범위가 너무 ...
# 6     기존 LMS의 구성 및 사용이 용이합니다. 필요한 몇 가지 정도만 부가된다면 좋을 ...
# 7                 현재 시스템에 만족함. 오픈형 플랫폼의 필요성은 딱히 느끼지 못함.
# 8             일반인은 무크 보면 되니까 굳이 필요없어 보이고 교우 대상으로는 괜찮을 듯
# 9
# 10    현재 불편함 없이 잘 사용하고 있으며, 저작권의 문제도 있을듯 하며, 최우선적으로는...
# 11                                 데이터 업데이트, 접속 오류의 문제
# 12
# 13                                         지금 것으로도 충분해서
# 14                                         현재 시스템에 만족해서
# 15    현 시스템도 충분히 제기능을 합니다. 완전히 새로운 시스템을 도입해야만 할 이유를 ...
# 16                               적응하는 데 시간이 오래 걸릴 것 같아서
# 17               오류가 지금보다 더 많이 발생할 것 같고 복잡해질 것 같기 때문이다.
# 18    더 유용한 시스템을 도입하기 보다는 현재 시스템을 잘 활용하는 것이 중요할 것 같습니다.
# 19    교수자 자료에 대한 저작권 문제도 고려해야 하고 학생들도 학비를 내고 강의를 수강하...
# ...

# %%
morphs_47 = []

for sentence in sen_47:
    morphs_47.append(okt.pos(sentence))
    
print(morphs_47)
# Out:
# [[('변경', 'Noun'), ('시', 'Noun'), ('혼란', 'Noun'), ('가중', 'Noun')], [('현재', 'Noun'), ('만족', 'Noun')], [], [('시스템', 'Noun'), ('불', 'Noun'), ('안정', 'Noun'), ('우려', 'Noun')], [('새', 'Noun'), ('시스템', 'Noun'), ('도입', 'Noun'), ('에', 'Josa'), ('따른', 'Verb'), ('효익', 'Noun'), ('이', 'Josa'), ('불확실하고', 'Adjective'), ('새로', 'Adjective'), ('적응하기가', 'Adjective'), ('불편함', 'Adjective')], [('교우', 'Noun'), ('와', 'Josa'), ('예비', 'Noun'), ('대학생', 'Noun'), ('에게는', 'Josa'), ('도움', 'Noun'), ('이', 'Josa'), ('될', 'Verb'), ('것', 'Noun'), ('같은데', 'Adjective'), ('일반인', 'Noun'), ('에게까지', 'Josa'), ('공개', 'Noun'), ('하는건', 'Verb'), ('범위', 'Noun'), ('가', 'Josa'), ('너무', 'Adverb'), ('넓은', 'Adjective'), ('것', 'Noun'), ('같습니다', 'Adjective'), ('.', 'Punctuation')], [('기존', 'Noun'), ('LMS', 'Alpha'), ('의', 'Noun'), ('구성', 'Noun'), ('및', 'Noun'), ('사용', 'Noun'), ('이', 'Josa'), ('용이합니다', 'Adjective'), ('.', 'Punctuation'), ('필요한', 'Adjective'), ('몇', 'Noun'), ('가지', 'Noun'), ('정도', 'Noun'), ('만', 'Josa'), ('부가', 'Noun'), ('된
# ...

# %%
noun_list_47 = []

for i in morphs_47:
    for word, tag in i:
        if (tag in ['Noun', 'Alpha']):
            noun_list_47.append(word)


from collections import Counter

count_47 = Counter(noun_list_47)
words_47 = (dict(count_47.most_common()))
print(words_47)
# Out:
# {'시스템': 45, '것': 37, '현재': 22, '블랙보드': 16, '도입': 14, '생각': 14, '사용': 10, '지금': 10, '학습': 10, '관리': 10, '때문': 9, '굳이': 7, '시간': 7, '외부': 7, '플랫폼': 6, '경우': 6, '기능': 6, '더': 6, '혼란': 5, '우려': 5, '문제': 5, '접속': 5, '학생': 5, '또': 5, '등': 5, '학교': 5, '시': 4, '안정': 4, '대상': 4, '자료': 4, '교수': 4, '오류': 4, '다른': 4, '차세대': 4, '수': 4, '가중': 3, '일반인': 3, '공개': 3, 'LMS': 3, '및': 3, 'Zoom': 3, '강연': 3, '강의': 3, '때': 3, '이유': 3, '발생': 3, '대한': 3, '변화': 3, '수업': 3, '필요': 3, '거': 3, '불편': 3, '교내': 3, '구성원': 3, '추가': 3, '서버': 3, '불': 2, '교우': 2, '기존': 2, '가지': 2, '정도': 2, '오픈': 2, '무크': 2, '저작권': 2, '녹화': 2, '과목': 2, '현': 2, '데': 2, '그': 2, '게': 2, '적응': 2, '그대로': 2, '구분': 2, '전반': 2, '다시': 2, '외': 2, '사용자': 2, '유입': 2, '자체': 2, '도': 2, '움': 2, '속도': 2, '사람': 2, '콘텐츠': 2, '현행': 2, '교육': 2, '요즘': 2, '이용자': 2, '분리': 2, '대면': 2, '변경': 1, '만족': 1, '새': 1, '효익': 1, '예비': 1, '대학생': 1, '도움': 1, '범위': 1, '의': 1, '구성': 1, '몇': 1, '부가': 1, '필요성': 1, '보이': 1, '듯': 1, '최우': 1, '선적': 1, '자': 1, '결정': 1, '끝': 1, '난후
# ...

# %%
for i in range(len(sen_47)):
    a = sen_47.iloc[i]
    sen_47.iloc[i] = a.lower()

for i in range(len(sen_47)):
    a = sen_47.iloc[i]
    sen_47.iloc[i] = a.replace('무크','kmooc')
    
for i in range(len(sen_47)):
    a = sen_47.iloc[i]
    sen_47.iloc[i] = a.replace('지금','현재')
    
for i in range(len(sen_47)):
    a = sen_47.iloc[i]
    sen_47.iloc[i] = a.replace('현 ','현재 ')
    
for i in range(len(sen_47)):
    a = sen_47.iloc[i]
    sen_47.iloc[i] = a.replace('현행','현재')
    
for i in range(len(sen_47)):
    a = sen_47.iloc[i]
    sen_47.iloc[i] = a.replace('기존','현재')

for i in range(len(sen_47)):
    a = sen_47.iloc[i]
    sen_47.iloc[i] = a.replace('현재도','현재')
    
for i in range(len(sen_47)):
    a = sen_47.iloc[i]
    sen_47.iloc[i] = a.replace('불편함','불편')
    
for i in range(len(sen_47)):
    a = sen_47.iloc[i]
    sen_47.iloc[i] = a.replace('불편할','불편 할')
    
for i in range(len(sen_47)):
    a = sen_47.iloc[i]
    sen_47.iloc[i] = a.replace('현재 시스템','현재 블랙보드 시스템')
    
for i in range(len(sen_47)):
    a = sen_47.iloc[i]
    sen_47.iloc[i] = a.replace('새 ','새로운 ')
    
for i in range(len(sen_47)):
    a = sen_47.iloc[i]
    sen_47.iloc[i] = a.replace('새로운 시스템','차세대 학습관리시스템')
    
for i in range(len(sen_47)):
    a = sen_47.iloc[i]
    sen_47.iloc[i] = a.replace('학교 구성원','교내 구성원')
    
for i in range(len(sen_47)):
    a = sen_47.iloc[i]
    sen_47.iloc[i] = a.replace('학교 소속','교내 구성원')
    
for i in range(len(sen_47)):
    a = sen_47.iloc[i]
    sen_47.iloc[i] = a.replace('학생들','재학생')
    
for i in range(len(sen_47)):
    a = sen_47.iloc[i]
    sen_47.iloc[i] = a.replace('외부인','일반인')
    
for i in range(len(sen_47)):
    a = sen_47.iloc[i]
    sen_47.iloc[i] = a.replace('현재 lms','현재 블랙보드 시스템')
    
for i in range(len(sen_47)):
    a = sen_47.iloc[i]
    sen_47.iloc[i] = a.replace('lms','학습관리시스템')
    
for i in range(len(sen_47)):
    a = sen_47.iloc[i]
    sen_47.iloc[i] = a.replace('현제 체제','현재 블랙보드 시스템')
    
for i in range(len(sen_47)):
    a = sen_47.iloc[i]
    sen_47.iloc[i] = a.replace('접근','접속')
    
for i in range(len(sen_47)):
    a = sen_47.iloc[i]
    sen_47.iloc[i] = a.replace('유입이','접속이')

# %%
sen_47
# Out:
# 0                                             변경시 혼란 가중
# 1                                                 현재 만족
# 2
# 3                                            시스템 불안정 우려
# 4              차세대 학습관리시스템 도입에 따른 효익이 불확실하고 새로 적응하기가 불편
# 5     교우와 예비대학생에게는 도움이 될 것 같은데 일반인에게까지 공개하는건 범위가 너무 ...
# 6     현재 블랙보드 시스템의 구성 및 사용이 용이합니다. 필요한 몇 가지 정도만 부가된다...
# 7            현재 블랙보드 시스템에 만족함. 오픈형 플랫폼의 필요성은 딱히 느끼지 못함.
# 8          일반인은 kmooc 보면 되니까 굳이 필요없어 보이고 교우 대상으로는 괜찮을 듯
# 9
# 10    현재 불편 없이 잘 사용하고 있으며, 저작권의 문제도 있을듯 하며, 최우선적으로는 ...
# 11                                 데이터 업데이트, 접속 오류의 문제
# 12
# 13                                         현재 것으로도 충분해서
# 14                                    현재 블랙보드 시스템에 만족해서
# 15    현재 블랙보드 시스템도 충분히 제기능을 합니다. 완전히 차세대 학습관리시스템을 도입...
# 16                               적응하는 데 시간이 오래 걸릴 것 같아서
# 17               오류가 현재보다 더 많이 발생할 것 같고 복잡해질 것 같기 때문이다.
# 18    더 유용한 시스템을 도입하기 보다는 현재 블랙보드 시스템을 잘 활용하는 것이 중요할...
# 19    교수자 자료에 대한 저작권 문제도 고려해야 하고 재학생도 학비를 내고 강의를 수강하...
# ...

# %%
morphs_47 = []

for sentence in sen_47:
    morphs_47.append(okt.pos(sentence))


noun_list_47 = []

for i in morphs_47:
    for word, tag in i:
        if (tag in ['Noun', 'Alpha']) and len(word) > 1 and ("경우" not in word) and ("때문" not in word) and ("대한" not in word) and ("생각" not in word):
            noun_list_47.append(word)


from collections import Counter

count_47 = Counter(noun_list_47)
words_47 = (dict(count_47.most_common()))
print(words_47)
# Out:
# {'시스템': 50, '현재': 39, '블랙보드': 31, '학습': 19, '관리': 19, '도입': 14, '차세대': 11, '사용': 10, '불편': 9, '일반인': 7, '굳이': 7, '접속': 7, '시간': 7, '플랫폼': 6, '기능': 6, '재학생': 6, '교내': 6, '혼란': 5, '우려': 5, '문제': 5, '안정': 4, '대상': 4, '자료': 4, '교수': 4, '오류': 4, '다른': 4, '구성원': 4, '가중': 3, '공개': 3, 'kmooc': 3, 'zoom': 3, '강연': 3, '강의': 3, '이유': 3, '발생': 3, '변화': 3, '수업': 3, '필요': 3, '외부': 3, '추가': 3, '서버': 3, '교우': 2, '가지': 2, '정도': 2, '오픈': 2, '저작권': 2, '녹화': 2, '과목': 2, '적응': 2, '그대로': 2, '구분': 2, '전반': 2, '다시': 2, '사용자': 2, '자체': 2, '학교': 2, '속도': 2, '사람': 2, '콘텐츠': 2, '교육': 2, '요즘': 2, '이용자': 2, '분리': 2, '대면': 2, '변경': 1, '만족': 1, '효익': 1, '예비': 1, '대학생': 1, '도움': 1, '범위': 1, '구성': 1, '부가': 1, '필요성': 1, '보이': 1, '최우': 1, '선적': 1, '결정': 1, '난후': 1, '진행': 1, '자동': 1, '검색': 1, '제공': 1, '데이터': 1, '업데이트': 1, '활용': 1, '고려': 1, '학비': 1, '수강': 1, '권리': 1, '존중': 1, '과정': 1, '대학': 1, '온라인': 1, '학습자': 1, '주요': 1, '자원': 1, '별로': 1, '얼마': 1, '이제야': 1, '개선': 1, '의도': 1, '보강': 1, '별도': 1, '자산': 1, '공유': 1, '편리': 1, 
# ...

# %%
# min-max normalization
df_47 = pd.DataFrame(words_47.values())
normalization_df_47 = (df_47 - df_47.min())/(df_47.max() - df_47.min())

a_47 = pd.concat([pd.DataFrame(words_47.keys()), normalization_df_47], axis=1).to_dict('split')['data']
a_47 = dict(a_47)

print(a_47)
# Out:
# {'시스템': 1.0, '현재': 0.7755102040816326, '블랙보드': 0.6122448979591837, '학습': 0.3673469387755102, '관리': 0.3673469387755102, '도입': 0.2653061224489796, '차세대': 0.20408163265306123, '사용': 0.1836734693877551, '불편': 0.16326530612244897, '일반인': 0.12244897959183673, '굳이': 0.12244897959183673, '접속': 0.12244897959183673, '시간': 0.12244897959183673, '플랫폼': 0.10204081632653061, '기능': 0.10204081632653061, '재학생': 0.10204081632653061, '교내': 0.10204081632653061, '혼란': 0.08163265306122448, '우려': 0.08163265306122448, '문제': 0.08163265306122448, '안정': 0.061224489795918366, '대상': 0.061224489795918366, '자료': 0.061224489795918366, '교수': 0.061224489795918366, '오류': 0.061224489795918366, '다른': 0.061224489795918366, '구성원': 0.061224489795918366, '가중': 0.04081632653061224, '공개': 0.04081632653061224, 'kmooc': 0.04081632653061224, 'zoom': 0.04081632653061224, '강연': 0.04081632653061224, '강의': 0.04081632653061224, '이유': 0.04081632653061224, '발생': 0.04081632653061224, '변화': 0.04081632653061224, '수업': 0.04081632653061224, 
# ...

# %%
wordcloud_47 = WordCloud(font_path = 'C:/Users/samsung/Downloads/BMJUA_ttf.ttf', width=3000, height=2000,
                          background_color = 'white', color_func=my_tf_color_func(a_47)).generate_from_frequencies(a_47) 

plt.imshow(wordcloud_47)
plt.axis('off')
plt.show()

# %%
## 여기까지
